# %% [markdown]
# <a href="https://colab.research.google.com/github/Nislainy/Data-Science/blob/main/an%C3%A1lise_alunos/dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Conhecendo a base de dados**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_csv('alunos.csv')

# %%
dados.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
dados.tail(5)
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %% [markdown]
# # **Características Gerais da base de dados**

# %%
dados.shape
# Out:
# (18, 4)

# %%
dados.columns
# Out:
# Index(['Nome', 'Idade', 'Notas', 'Aprovado'], dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 578.0+ bytes

# %%
dados.dtypes
# Out:
# Nome         object
# Idade         int64
# Notas       float64
# Aprovado       bool
# dtype: object

# %%
dados['Notas']
# Out:
# 0      7.5
# 1      NaN
# 2      2.5
# 3      5.0
# 4     10.0
# 5      NaN
# 6      7.0
# 7      6.0
# 8      5.6
# 9      NaN
# 10     NaN
# 11     4.5
# 12     9.5
# 13     9.0
# 14     NaN
# 15     7.0
# 16     NaN
# 17     8.0
# Name: Notas, dtype: float64

# %%
resumo = dados['Notas'].describe()
print(resumo)
# Out:
# count    16.000000
# mean      7.500000
# std       1.914854
# min       2.500000
# 25%       7.875000
# 50%       8.000000
# 75%       8.000000
# max      10.000000
# Name: Notas, dtype: float64

# %% [markdown]
# # **Manipulando Dados**

# %%
dados.head()
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True

# %%
dados = dados.sort_values('Notas', ascending=False)
dados = dados.reset_index(drop=True)
dados.head(20)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0        Beto     21   10.0      True
# 1   Sthefanie     26    9.5      True
# 2       Mirla     25    9.0      True
# 3       Nadia     34    8.0      True
# 4         Ary     20    7.5      True
# 5        Dara     21    7.0      True
# 6      Mylena     29    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Denis     18    5.0     False
# 10       Igor     24    4.5     False
# 11      Cátia     27    2.5     False
# 12        Ana     18    NaN     False
# 13      Bruna     23    NaN     False
# 14      Vitor     28    NaN     False
# 15     Daniel     21    NaN     False
# 16      Paulo     37    NaN     False
# 17      Lucas     33    NaN     False

# %%
mudança_nome_coluna = dados.rename(columns={'Aprovado': 'Categoria'}, inplace=True)
dados.head(20)
# Out:
#          Nome  Idade  Notas  Categoria
# 0        Beto     21   10.0       True
# 1   Sthefanie     26    9.5       True
# 2       Mirla     25    9.0       True
# 3       Nadia     34    8.0       True
# 4         Ary     20    7.5       True
# 5        Dara     21    7.0       True
# 6      Mylena     29    7.0       True
# 7      Carlos     19    6.0       True
# 8       Alice     35    5.6      False
# 9       Denis     18    5.0      False
# 10       Igor     24    4.5      False
# 11      Cátia     27    2.5      False
# 12        Ana     18    NaN      False
# 13      Bruna     23    NaN      False
# 14      Vitor     28    NaN      False
# 15     Daniel     21    NaN      False
# 16      Paulo     37    NaN      False
# 17      Lucas     33    NaN      False

# %%
dados.loc[dados['Categoria'] == True, 'Categoria'] = 'Aprovado'
dados.loc[dados['Categoria'] == False, 'Categoria'] = 'Reprovado'
dados.head(20)
# Out:
#          Nome  Idade  Notas  Categoria
# 0        Beto     21   10.0   Aprovado
# 1   Sthefanie     26    9.5   Aprovado
# 2       Mirla     25    9.0   Aprovado
# 3       Nadia     34    8.0   Aprovado
# 4         Ary     20    7.5   Aprovado
# 5        Dara     21    7.0   Aprovado
# 6      Mylena     29    7.0   Aprovado
# 7      Carlos     19    6.0   Aprovado
# 8       Alice     35    5.6  Reprovado
# 9       Denis     18    5.0  Reprovado
# 10       Igor     24    4.5  Reprovado
# 11      Cátia     27    2.5  Reprovado
# 12        Ana     18    NaN  Reprovado
# 13      Bruna     23    NaN  Reprovado
# 14      Vitor     28    NaN  Reprovado
# 15     Daniel     21    NaN  Reprovado
# 16      Paulo     37    NaN  Reprovado
# 17      Lucas     33    NaN  Reprovado

# %% [markdown]
# # **Estatistica Descritiva**

# %%
dados.head(20)
# Out:
#          Nome  Idade  Notas  Categoria
# 0        Beto     21   10.0   Aprovado
# 1   Sthefanie     26    9.5   Aprovado
# 2       Mirla     25    9.0   Aprovado
# 3       Nadia     34    8.0   Aprovado
# 4         Ary     20    7.5   Aprovado
# 5        Dara     21    7.0   Aprovado
# 6      Mylena     29    7.0   Aprovado
# 7      Carlos     19    6.0   Aprovado
# 8       Alice     35    5.6  Reprovado
# 9       Denis     18    5.0  Reprovado
# 10       Igor     24    4.5  Reprovado
# 11      Cátia     27    2.5  Reprovado
# 12        Ana     18    NaN  Reprovado
# 13      Bruna     23    NaN  Reprovado
# 14      Vitor     28    NaN  Reprovado
# 15     Daniel     21    NaN  Reprovado
# 16      Paulo     37    NaN  Reprovado
# 17      Lucas     33    NaN  Reprovado

# %%
media_idade = dados['Idade'].mean()
print('A média da idade é:', media_idade)
media_notas = dados['Notas'].mean()
print('A média das notas é:', media_notas)
# Out:
# A média da idade é: 25.5
# A média das notas é: 6.8

# %%
mediana_notas = dados['Notas'].median()
print('A mediana das notas equivale a:', mediana_notas)
# Out:
# A mediana das notas equivale a: 7.0

# %%
dados['Notas'].mode()[0]
# Out:
# 7.0

# %%
dados[['Idade', 'Notas']].std()
# Out:
# Idade    6.070662
# Notas    2.204953
# dtype: float64

# %% [markdown]
# # **Tratando Valores NaN**

# %% [markdown]
# ### **Lidando com dados nulos**

# %%
dados.head(20)
# Out:
#          Nome  Idade  Notas  Categoria
# 0        Beto     21   10.0   Aprovado
# 1   Sthefanie     26    9.5   Aprovado
# 2       Mirla     25    9.0   Aprovado
# 3       Nadia     34    8.0   Aprovado
# 4         Ary     20    7.5   Aprovado
# 5        Dara     21    7.0   Aprovado
# 6      Mylena     29    7.0   Aprovado
# 7      Carlos     19    6.0   Aprovado
# 8       Alice     35    5.6  Reprovado
# 9       Denis     18    5.0  Reprovado
# 10       Igor     24    4.5  Reprovado
# 11      Cátia     27    2.5  Reprovado
# 12        Ana     18    NaN  Reprovado
# 13      Bruna     23    NaN  Reprovado
# 14      Vitor     28    NaN  Reprovado
# 15     Daniel     21    NaN  Reprovado
# 16      Paulo     37    NaN  Reprovado
# 17      Lucas     33    NaN  Reprovado

# %%
dados.isnull()
# Out:
#      Nome  Idade  Notas  Categoria
# 0   False  False  False      False
# 1   False  False  False      False
# 2   False  False  False      False
# 3   False  False  False      False
# 4   False  False  False      False
# 5   False  False  False      False
# 6   False  False  False      False
# 7   False  False  False      False
# 8   False  False  False      False
# 9   False  False  False      False
# 10  False  False  False      False
# 11  False  False  False      False
# 12  False  False   True      False
# 13  False  False   True      False
# 14  False  False   True      False
# 15  False  False   True      False
# 16  False  False   True      False
# 17  False  False   True      False

# %%
dados.isnull().sum()
# Out:
# Nome         0
# Idade        0
# Notas        6
# Categoria    0
# dtype: int64

# %%
dados.fillna(7.0, inplace=True)
dados.head(18)
# Out:
#          Nome  Idade  Notas  Categoria
# 0        Beto     21   10.0   Aprovado
# 1   Sthefanie     26    9.5   Aprovado
# 2       Mirla     25    9.0   Aprovado
# 3       Nadia     34    8.0   Aprovado
# 4         Ary     20    7.5   Aprovado
# 5        Dara     21    7.0   Aprovado
# 6      Mylena     29    7.0   Aprovado
# 7      Carlos     19    6.0   Aprovado
# 8       Alice     35    5.6  Reprovado
# 9       Denis     18    5.0  Reprovado
# 10       Igor     24    4.5  Reprovado
# 11      Cátia     27    2.5  Reprovado
# 12        Ana     18    7.0  Reprovado
# 13      Bruna     23    7.0  Reprovado
# 14      Vitor     28    7.0  Reprovado
# 15     Daniel     21    7.0  Reprovado
# 16      Paulo     37    7.0  Reprovado
# 17      Lucas     33    7.0  Reprovado

# %%
dados.isnull().sum()
# Out:
# Nome         0
# Idade        0
# Notas        0
# Categoria    0
# dtype: int64

# %%
valores_unicos = dados['Notas'].unique()
print(valores_unicos)
# Out:
# [10.   9.5  9.   8.   7.5  7.   6.   5.6  5.   4.5  2.5]

# %% [markdown]
# # **Análises**

# %%
dados.head(20)
# Out:
#          Nome  Idade  Notas  Categoria
# 0        Beto     21   10.0   Aprovado
# 1   Sthefanie     26    9.5   Aprovado
# 2       Mirla     25    9.0   Aprovado
# 3       Nadia     34    8.0   Aprovado
# 4         Ary     20    7.5   Aprovado
# 5        Dara     21    7.0   Aprovado
# 6      Mylena     29    7.0   Aprovado
# 7      Carlos     19    6.0   Aprovado
# 8       Alice     35    5.6  Reprovado
# 9       Denis     18    5.0  Reprovado
# 10       Igor     24    4.5  Reprovado
# 11      Cátia     27    2.5  Reprovado
# 12        Ana     18    7.0  Reprovado
# 13      Bruna     23    7.0  Reprovado
# 14      Vitor     28    7.0  Reprovado
# 15     Daniel     21    7.0  Reprovado
# 16      Paulo     37    7.0  Reprovado
# 17      Lucas     33    7.0  Reprovado

# %%
notas_categorias = dados[['Notas', 'Categoria']]
print(notas_categorias)
# Out:
#     Notas  Categoria
# 0    10.0   Aprovado
# 1     9.5   Aprovado
# 2     9.0   Aprovado
# 3     8.0   Aprovado
# 4     7.5   Aprovado
# 5     7.0   Aprovado
# 6     7.0   Aprovado
# 7     6.0   Aprovado
# 8     5.6  Reprovado
# 9     5.0  Reprovado
# 10    4.5  Reprovado
# 11    2.5  Reprovado
# 12    7.0  Reprovado
# 13    7.0  Reprovado
# 14    7.0  Reprovado
# 15    7.0  Reprovado
# 16    7.0  Reprovado
# 17    7.0  Reprovado

# %%
dados['Situação'] = np.where(dados['Notas'] >= 7, 'Aprovado', 'Reprovado')
dados.head(20)
# Out:
#          Nome  Idade  Notas  Categoria   Situação
# 0        Beto     21   10.0   Aprovado   Aprovado
# 1   Sthefanie     26    9.5   Aprovado   Aprovado
# 2       Mirla     25    9.0   Aprovado   Aprovado
# 3       Nadia     34    8.0   Aprovado   Aprovado
# 4         Ary     20    7.5   Aprovado   Aprovado
# 5        Dara     21    7.0   Aprovado   Aprovado
# 6      Mylena     29    7.0   Aprovado   Aprovado
# 7      Carlos     19    6.0   Aprovado  Reprovado
# 8       Alice     35    5.6  Reprovado  Reprovado
# 9       Denis     18    5.0  Reprovado  Reprovado
# 10       Igor     24    4.5  Reprovado  Reprovado
# 11      Cátia     27    2.5  Reprovado  Reprovado
# 12        Ana     18    7.0  Reprovado   Aprovado
# 13      Bruna     23    7.0  Reprovado   Aprovado
# 14      Vitor     28    7.0  Reprovado   Aprovado
# 15     Daniel     21    7.0  Reprovado   Aprovado
# 16      Paulo     37    7.0  Reprovado   Aprovado
# 17      Lucas     33    7.0  Reprovado   Aprovado

# %% [markdown]
# # **Remoção**

# %% [markdown]
# ### **Remoção de Coluna**

# %%
dados.head(20)
# Out:
#          Nome  Idade  Notas  Categoria   Situação
# 0        Beto     21   10.0   Aprovado   Aprovado
# 1   Sthefanie     26    9.5   Aprovado   Aprovado
# 2       Mirla     25    9.0   Aprovado   Aprovado
# 3       Nadia     34    8.0   Aprovado   Aprovado
# 4         Ary     20    7.5   Aprovado   Aprovado
# 5        Dara     21    7.0   Aprovado   Aprovado
# 6      Mylena     29    7.0   Aprovado   Aprovado
# 7      Carlos     19    6.0   Aprovado  Reprovado
# 8       Alice     35    5.6  Reprovado  Reprovado
# 9       Denis     18    5.0  Reprovado  Reprovado
# 10       Igor     24    4.5  Reprovado  Reprovado
# 11      Cátia     27    2.5  Reprovado  Reprovado
# 12        Ana     18    7.0  Reprovado   Aprovado
# 13      Bruna     23    7.0  Reprovado   Aprovado
# 14      Vitor     28    7.0  Reprovado   Aprovado
# 15     Daniel     21    7.0  Reprovado   Aprovado
# 16      Paulo     37    7.0  Reprovado   Aprovado
# 17      Lucas     33    7.0  Reprovado   Aprovado

# %%
dados = dados.drop('Categoria', axis=1)
dados.head()
# Out:
#         Nome  Idade  Notas  Situação
# 0       Beto     21   10.0  Aprovado
# 1  Sthefanie     26    9.5  Aprovado
# 2      Mirla     25    9.0  Aprovado
# 3      Nadia     34    8.0  Aprovado
# 4        Ary     20    7.5  Aprovado

# %% [markdown]
# ### **Remoção de Alunos**

# %%
dados.head()
# Out:
#         Nome  Idade  Notas  Situação
# 0       Beto     21   10.0  Aprovado
# 1  Sthefanie     26    9.5  Aprovado
# 2      Mirla     25    9.0  Aprovado
# 3      Nadia     34    8.0  Aprovado
# 4        Ary     20    7.5  Aprovado

# %%
dados.Nome.unique()
# Out:
# array(['Beto', 'Sthefanie', 'Mirla', 'Nadia', 'Ary', 'Dara', 'Mylena',
#        'Carlos', 'Alice', 'Denis', 'Igor', 'Cátia', 'Ana', 'Bruna',
#        'Vitor', 'Daniel', 'Paulo', 'Lucas'], dtype=object)

# %%
alunos_a_remover = dados.query('Nome == "Alice" | Nome == "Carlos"').index

# %%
dados.drop(alunos_a_remover, axis=0, inplace=True)

# %%
dados.head()
# Out:
#         Nome  Idade  Notas  Situação
# 0       Beto     21   10.0  Aprovado
# 1  Sthefanie     26    9.5  Aprovado
# 2      Mirla     25    9.0  Aprovado
# 3      Nadia     34    8.0  Aprovado
# 4        Ary     20    7.5  Aprovado

# %%
dados.Nome.unique()
# Out:
# array(['Beto', 'Sthefanie', 'Mirla', 'Nadia', 'Ary', 'Dara', 'Mylena',
#        'Denis', 'Igor', 'Cátia', 'Ana', 'Bruna', 'Vitor', 'Daniel',
#        'Paulo', 'Lucas'], dtype=object)

# %% [markdown]
# ### **Após remoção, análise da: Moda, Média, Mediana e Desvio**

# %%
media_notas = dados['Notas'].mean()
print('A média das notas é:', media_notas)
# Out:
# A média das notas é: 7.0

# %%
mediana_notas = dados['Notas'].median()
print('A mediana das notas equivale a:', mediana_notas)
# Out:
# A mediana das notas equivale a: 7.0

# %%
dados['Notas'].mode()[0]
# Out:
# 7.0

# %%
dados['Notas'].std()
# Out:
# 1.8439088914585775

# %% [markdown]
# # **Dados Alunos**

# %% [markdown]
# ### **Alunos Aprovados**

# %%
dados.head(20)
# Out:
#          Nome  Idade  Notas   Situação
# 0        Beto     21   10.0   Aprovado
# 1   Sthefanie     26    9.5   Aprovado
# 2       Mirla     25    9.0   Aprovado
# 3       Nadia     34    8.0   Aprovado
# 4         Ary     20    7.5   Aprovado
# 5        Dara     21    7.0   Aprovado
# 6      Mylena     29    7.0   Aprovado
# 9       Denis     18    5.0  Reprovado
# 10       Igor     24    4.5  Reprovado
# 11      Cátia     27    2.5  Reprovado
# 12        Ana     18    7.0   Aprovado
# 13      Bruna     23    7.0   Aprovado
# 14      Vitor     28    7.0   Aprovado
# 15     Daniel     21    7.0   Aprovado
# 16      Paulo     37    7.0   Aprovado
# 17      Lucas     33    7.0   Aprovado

# %%
nota_maxima = dados['Notas'].max()
nota_minima = dados['Notas'].min()

print("A nota máxima é:", nota_maxima)
print("A nota mínima é:", nota_minima)
# Out:
# A nota máxima é: 10.0
# A nota mínima é: 2.5

# %%
alunos_aprovados = dados['Situação'] == 'Aprovado'
dados[alunos_aprovados]
# Out:
#          Nome  Idade  Notas  Situação
# 0        Beto     21   10.0  Aprovado
# 1   Sthefanie     26    9.5  Aprovado
# 2       Mirla     25    9.0  Aprovado
# 3       Nadia     34    8.0  Aprovado
# 4         Ary     20    7.5  Aprovado
# 5        Dara     21    7.0  Aprovado
# 6      Mylena     29    7.0  Aprovado
# 12        Ana     18    7.0  Aprovado
# 13      Bruna     23    7.0  Aprovado
# 14      Vitor     28    7.0  Aprovado
# 15     Daniel     21    7.0  Aprovado
# 16      Paulo     37    7.0  Aprovado
# 17      Lucas     33    7.0  Aprovado

# %%
dados_aprovados = dados[dados['Situação'] == 'Aprovado']
idade_media_aprovados = dados_aprovados['Idade'].mean()
print('A idade média dos alunos aprovados é: ', idade_media_aprovados)
# Out:
# A idade média dos alunos aprovados é:  25.846153846153847

# %%
contagem_situacao = dados['Situação'].value_counts()
porcentagem_aprovados = (contagem_situacao['Aprovado'] / len(dados)) * 100
print('A porcentagem de alunos aprovados é: ',porcentagem_aprovados)
# Out:
# A porcentagem de alunos aprovados é:  81.25

# %% [markdown]
# ### **Alunos Reprovados**

# %%
alunos_reprovados = dados['Situação'] == 'Reprovado'
dados[alunos_reprovados]
# Out:
#      Nome  Idade  Notas   Situação
# 9   Denis     18    5.0  Reprovado
# 10   Igor     24    4.5  Reprovado
# 11  Cátia     27    2.5  Reprovado

# %%
dados_reprovados = dados[dados['Situação'] == 'Reprovado']
porcentagem_reprovados = dados_reprovados['Idade'].mean()
print('A idade média dos alunos reprovados é: ' ,porcentagem_reprovados)
# Out:
# A idade média dos alunos reprovados é:  23.0

# %%
contagem_situacao = dados['Situação'].value_counts()
porcentagem_reprovados = (contagem_situacao['Reprovado'] / len(dados)) * 100
print('A porcentagem de alunos reprovados é: ',porcentagem_reprovados)
# Out:
# A porcentagem de alunos reprovados é:  18.75

# %% [markdown]
# # **Salvar**

# %%
alunos_aprovados = dados[alunos_aprovados ]

# %%
alunos_aprovados.to_csv('alunos_aprovados.csv', index=False)
dados.head()
# Out:
#         Nome  Idade  Notas  Situação
# 0       Beto     21   10.0  Aprovado
# 1  Sthefanie     26    9.5  Aprovado
# 2      Mirla     25    9.0  Aprovado
# 3      Nadia     34    8.0  Aprovado
# 4        Ary     20    7.5  Aprovado

# %% [markdown]
# # **Gráficos**

# %% [markdown]
# ### **Análise por % alunos Aprovados e Reprovados**

# %%
dados.head(20)
# Out:
#          Nome  Idade  Notas   Situação
# 0        Beto     21   10.0   Aprovado
# 1   Sthefanie     26    9.5   Aprovado
# 2       Mirla     25    9.0   Aprovado
# 3       Nadia     34    8.0   Aprovado
# 4         Ary     20    7.5   Aprovado
# 5        Dara     21    7.0   Aprovado
# 6      Mylena     29    7.0   Aprovado
# 9       Denis     18    5.0  Reprovado
# 10       Igor     24    4.5  Reprovado
# 11      Cátia     27    2.5  Reprovado
# 12        Ana     18    7.0   Aprovado
# 13      Bruna     23    7.0   Aprovado
# 14      Vitor     28    7.0   Aprovado
# 15     Daniel     21    7.0   Aprovado
# 16      Paulo     37    7.0   Aprovado
# 17      Lucas     33    7.0   Aprovado

# %%
dados = dados.sort_values('Notas', ascending=False)
dados = dados.reset_index(drop=True)
dados.head(20)
# Out:
#          Nome  Idade  Notas   Situação
# 0        Beto     21   10.0   Aprovado
# 1   Sthefanie     26    9.5   Aprovado
# 2       Mirla     25    9.0   Aprovado
# 3       Nadia     34    8.0   Aprovado
# 4         Ary     20    7.5   Aprovado
# 5        Dara     21    7.0   Aprovado
# 6      Mylena     29    7.0   Aprovado
# 7         Ana     18    7.0   Aprovado
# 8       Bruna     23    7.0   Aprovado
# 9       Vitor     28    7.0   Aprovado
# 10     Daniel     21    7.0   Aprovado
# 11      Paulo     37    7.0   Aprovado
# 12      Lucas     33    7.0   Aprovado
# 13      Denis     18    5.0  Reprovado
# 14       Igor     24    4.5  Reprovado
# 15      Cátia     27    2.5  Reprovado

# %%
dados.head(20)
print(dados.columns)
# Out:
# Index(['Nome', 'Idade', 'Notas', 'Situação'], dtype='object')

# %%
total_aprovado_reprovado = dados['Situação'].value_counts()
total_aprovado_reprovado
# Out:
# Aprovado     13
# Reprovado     3
# Name: Situação, dtype: int64

# %%
aprovados = dados[dados['Situação'] == 'Aprovado'].shape[0]
reprovados = dados[dados['Situação'] == 'Reprovado'].shape[0]

# %%
total_alunos = aprovados + reprovados
porcentagem_aprovados = (aprovados / total_alunos) * 100
porcentagem_reprovados = (reprovados / total_alunos) * 100

# %%
labels = ['Aprovados', 'Reprovados']
sizes = [porcentagem_aprovados, porcentagem_reprovados]

# %%
labels = ['Aprovados', 'Reprovados']
sizes = [porcentagem_aprovados, porcentagem_reprovados]

# %%
colors = ['Purple', '#C8A2C8']
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors)
plt.axis('equal')
plt.title('Porcentagem de Alunos Aprovados e Reprovados')

plt.show()

# %% [markdown]
# # **Correção de notas**

# %% [markdown]
# ### **Alunos que tiraram 7.0, ajustar para 8.0**

# %%
dados.head(20)
# Out:
#          Nome  Idade  Notas   Situação
# 0        Beto     21   10.0   Aprovado
# 1   Sthefanie     26    9.5   Aprovado
# 2       Mirla     25    9.0   Aprovado
# 3       Nadia     34    8.0   Aprovado
# 4         Ary     20    7.5   Aprovado
# 5        Dara     21    7.0   Aprovado
# 6      Mylena     29    7.0   Aprovado
# 7         Ana     18    7.0   Aprovado
# 8       Bruna     23    7.0   Aprovado
# 9       Vitor     28    7.0   Aprovado
# 10     Daniel     21    7.0   Aprovado
# 11      Paulo     37    7.0   Aprovado
# 12      Lucas     33    7.0   Aprovado
# 13      Denis     18    5.0  Reprovado
# 14       Igor     24    4.5  Reprovado
# 15      Cátia     27    2.5  Reprovado

# %%
dados['Notas'] = dados['Notas'].replace(7, 8)
dados.head(20)
# Out:
#          Nome  Idade  Notas   Situação
# 0        Beto     21   10.0   Aprovado
# 1   Sthefanie     26    9.5   Aprovado
# 2       Mirla     25    9.0   Aprovado
# 3       Nadia     34    8.0   Aprovado
# 4         Ary     20    7.5   Aprovado
# 5        Dara     21    8.0   Aprovado
# 6      Mylena     29    8.0   Aprovado
# 7         Ana     18    8.0   Aprovado
# 8       Bruna     23    8.0   Aprovado
# 9       Vitor     28    8.0   Aprovado
# 10     Daniel     21    8.0   Aprovado
# 11      Paulo     37    8.0   Aprovado
# 12      Lucas     33    8.0   Aprovado
# 13      Denis     18    5.0  Reprovado
# 14       Igor     24    4.5  Reprovado
# 15      Cátia     27    2.5  Reprovado

# %%
resumo = dados['Notas'].describe()
print(resumo)
# Out:
# count    16.000000
# mean      7.500000
# std       1.914854
# min       2.500000
# 25%       7.875000
# 50%       8.000000
# 75%       8.000000
# max      10.000000
# Name: Notas, dtype: float64

# %%
dados['Notas'].mode()[0]
# Out:
# 8.0

# %% [markdown]
# # **Criando Colunas**

# %% [markdown]
# ### **Atividade Extracurricular: 40% da nota atual**

# %%
dados.head(20)
# Out:
#          Nome  Idade  Notas   Situação
# 0        Beto     21   10.0   Aprovado
# 1   Sthefanie     26    9.5   Aprovado
# 2       Mirla     25    9.0   Aprovado
# 3       Nadia     34    8.0   Aprovado
# 4         Ary     20    7.5   Aprovado
# 5        Dara     21    8.0   Aprovado
# 6      Mylena     29    8.0   Aprovado
# 7         Ana     18    8.0   Aprovado
# 8       Bruna     23    8.0   Aprovado
# 9       Vitor     28    8.0   Aprovado
# 10     Daniel     21    8.0   Aprovado
# 11      Paulo     37    8.0   Aprovado
# 12      Lucas     33    8.0   Aprovado
# 13      Denis     18    5.0  Reprovado
# 14       Igor     24    4.5  Reprovado
# 15      Cátia     27    2.5  Reprovado

# %%
dados['Pontos_extras'] = dados['Notas'].apply(lambda x: x*0.4)
dados
# Out:
#          Nome  Idade  Notas   Situação  Pontos_extras
# 0        Beto     21   10.0   Aprovado            4.0
# 1   Sthefanie     26    9.5   Aprovado            3.8
# 2       Mirla     25    9.0   Aprovado            3.6
# 3       Nadia     34    8.0   Aprovado            3.2
# 4         Ary     20    7.5   Aprovado            3.0
# 5        Dara     21    8.0   Aprovado            3.2
# 6      Mylena     29    8.0   Aprovado            3.2
# 7         Ana     18    8.0   Aprovado            3.2
# 8       Bruna     23    8.0   Aprovado            3.2
# 9       Vitor     28    8.0   Aprovado            3.2
# 10     Daniel     21    8.0   Aprovado            3.2
# 11      Paulo     37    8.0   Aprovado            3.2
# 12      Lucas     33    8.0   Aprovado            3.2
# 13      Denis     18    5.0  Reprovado            2.0
# 14       Igor     24    4.5  Reprovado            1.8
# 15      Cátia     27    2.5  Reprovado            1.0

# %%
dados['Notas_finais'] = dados['Notas'] + dados['Pontos_extras']
dados
# Out:
#          Nome  Idade  Notas   Situação  Pontos_extras  Notas_finais
# 0        Beto     21   10.0   Aprovado            4.0          14.0
# 1   Sthefanie     26    9.5   Aprovado            3.8          13.3
# 2       Mirla     25    9.0   Aprovado            3.6          12.6
# 3       Nadia     34    8.0   Aprovado            3.2          11.2
# 4         Ary     20    7.5   Aprovado            3.0          10.5
# 5        Dara     21    8.0   Aprovado            3.2          11.2
# 6      Mylena     29    8.0   Aprovado            3.2          11.2
# 7         Ana     18    8.0   Aprovado            3.2          11.2
# 8       Bruna     23    8.0   Aprovado            3.2          11.2
# 9       Vitor     28    8.0   Aprovado            3.2          11.2
# 10     Daniel     21    8.0   Aprovado            3.2          11.2
# 11      Paulo     37    8.0   Aprovado            3.2          11.2
# 12      Lucas     33    8.0   Aprovado            3.2          11.2
# ...

# %%
dados['Aprovado_final'] = dados['Notas_finais'].apply(lambda x: True if x >= 7 else False)
dados
# Out:
#          Nome  Idade  Notas   Situação  Pontos_extras  Notas_finais  \
# 0        Beto     21   10.0   Aprovado            4.0          14.0
# 1   Sthefanie     26    9.5   Aprovado            3.8          13.3
# 2       Mirla     25    9.0   Aprovado            3.6          12.6
# 3       Nadia     34    8.0   Aprovado            3.2          11.2
# 4         Ary     20    7.5   Aprovado            3.0          10.5
# 5        Dara     21    8.0   Aprovado            3.2          11.2
# 6      Mylena     29    8.0   Aprovado            3.2          11.2
# 7         Ana     18    8.0   Aprovado            3.2          11.2
# 8       Bruna     23    8.0   Aprovado            3.2          11.2
# 9       Vitor     28    8.0   Aprovado            3.2          11.2
# 10     Daniel     21    8.0   Aprovado            3.2          11.2
# 11      Paulo     37    8.0   Aprovado            3.2          11.2
# 12      Lucas     33    8.0   Aprovado            3.2          11.2
# ...

# %%
dados['Aprovado_final'] = dados['Aprovado_final'].replace({True: 'Aprovado', False: 'Reprovado'})
print(dados.to_string(index=False))
# Out:
#      Nome  Idade  Notas  Situação  Pontos_extras  Notas_finais Aprovado_final
#      Beto     21   10.0  Aprovado            4.0          14.0       Aprovado
# Sthefanie     26    9.5  Aprovado            3.8          13.3       Aprovado
#     Mirla     25    9.0  Aprovado            3.6          12.6       Aprovado
#     Nadia     34    8.0  Aprovado            3.2          11.2       Aprovado
#       Ary     20    7.5  Aprovado            3.0          10.5       Aprovado
#      Dara     21    8.0  Aprovado            3.2          11.2       Aprovado
#    Mylena     29    8.0  Aprovado            3.2          11.2       Aprovado
#       Ana     18    8.0  Aprovado            3.2          11.2       Aprovado
#     Bruna     23    8.0  Aprovado            3.2          11.2       Aprovado
#     Vitor     28    8.0  Aprovado            3.2          11.2       Aprovado
#    Daniel     21    8.0  Aprovado            3.2          11.2       Aprovado
# ...

# %%
dados.query('Aprovado_final == "Reprovado" | Aprovado_final == "Aprovado"')
# Out:
#          Nome  Idade  Notas   Situação  Pontos_extras  Notas_finais  \
# 0        Beto     21   10.0   Aprovado            4.0          14.0
# 1   Sthefanie     26    9.5   Aprovado            3.8          13.3
# 2       Mirla     25    9.0   Aprovado            3.6          12.6
# 3       Nadia     34    8.0   Aprovado            3.2          11.2
# 4         Ary     20    7.5   Aprovado            3.0          10.5
# 5        Dara     21    8.0   Aprovado            3.2          11.2
# 6      Mylena     29    8.0   Aprovado            3.2          11.2
# 7         Ana     18    8.0   Aprovado            3.2          11.2
# 8       Bruna     23    8.0   Aprovado            3.2          11.2
# 9       Vitor     28    8.0   Aprovado            3.2          11.2
# 10     Daniel     21    8.0   Aprovado            3.2          11.2
# 11      Paulo     37    8.0   Aprovado            3.2          11.2
# 12      Lucas     33    8.0   Aprovado            3.2          11.2
# ...

# %%
selecao = (dados['Situação'] == 'Reprovado') & (dados['Aprovado_final'] == 'Aprovado')
resultado = dados.loc[selecao]
resultado.head()
# Out:
#      Nome  Idade  Notas   Situação  Pontos_extras  Notas_finais Aprovado_final
# 13  Denis     18    5.0  Reprovado            2.0           7.0       Aprovado

# %%
resumo = dados['Notas_finais'].describe()
print(resumo)
# Out:
# count    16.000000
# mean     10.500000
# std       2.680796
# min       3.500000
# 25%      11.025000
# 50%      11.200000
# 75%      11.200000
# max      14.000000
# Name: Notas_finais, dtype: float64

# %%
dados['Notas_finais'].mode()[0]
# Out:
# 11.2
